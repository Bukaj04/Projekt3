# %% [markdown]
# <h1> Techniki programowania - Projekt 3</h1>
# <h1>Autorzy:</h1>
# <h2>Albert Piątkowski 197691</h2>
# <h2>Jakub Piotrowicz 197760</h2>

# %% [markdown]
# wykorzystane biblioteki:
#
# matplotplusplus(c++)</br>
# AudioFile(c++)</br>
# pybind11

# %% [markdown]
# <h1>Generowanie sygnałów o zadanej częstotliwości (sin, cos, prostokątny, piłokształtny)</h1>

# %%
import scikit_build_example as script

script.rysowanie_wykresow_podstawowych()

# %% [markdown]
# funkcja przyjmuje parametry:
# <li>częstotliwość</li>
# <li>typ wykresu</li>

# %% [markdown]
# dla poniższych wykresów częstotliwość wynosi 10

# %% [markdown]
# <h2>Wykres funkcji sinus</h2>

# %% [markdown]
# ![sinus.png](attachment:5e476949-432f-4d7c-b7b5-6b5b76a92d5a.png)

# %% [markdown]
# <h2>Wykres funkcji cosinus</h2>

# %% [markdown]
# ![cos.png](attachment:3ea6e819-bbe8-4b84-97be-6e0ebfb1d52f.png)

# %% [markdown]
# <h2>Wykres prostokątny</h2>

# %% [markdown]
# ![prostokatny.png](attachment:1a7b8eea-026e-40a4-9362-f2f0752e6c5c.png)

# %% [markdown]
# <h1>Wykres piłokształtny</h1>

# %% [markdown]
# ![piloksztaltny.png](attachment:adcf9eea-764c-461e-9e81-f5d3575d4630.png)

# %% [markdown]
# <h1>Generowanie wykresów przefiltrowanych</h1>

# %%
import scikit_build_example as script

script.rysowanie_wykresow_filtr()

# %% [markdown]
# funkcja przyjmuje parametry:
# <li>częstotliwość</li>
# <li>częstotliwość graniczna</li>
# <li>próbkowanie</li>
# <li>rząd filtru</li>
# <li>typ wykresu</li>

# %% [markdown]
# <h1>Przefiltrowany sinus</h1>
# <li>częstotliwość: 5</li>
# <li>częstotliwość graniczna: 2 </li>
# <li>próbkowanie: 1200</li>
# <li>rząd filtru: 200</li>

# %% [markdown]
# ![sinf.png](attachment:a4033e6f-52ee-49d8-be44-c2f2ca8d28d4.png)

# %% [markdown]
# <h1>Przefiltrowany cosinus</h1>
# <li>częstotliwość: 10</li>
# <li>częstotliwość graniczna: 2 </li>
# <li>próbkowanie: 200</li>
# <li>rząd filtru: 520</li>

# %% [markdown]
# ![cosf.png](attachment:b7494564-451c-497d-aa0f-b447369c8f5a.png)

# %% [markdown]
# <h1>Przefiltrowany sygnał prostokątny</h1>
# <li>częstotliwość: 3</li>
# <li>częstotliwość graniczna: 9 </li>
# <li>próbkowanie: 150</li>
# <li>rząd filtru: 130</li>

# %% [markdown]
# ![prosf.png](attachment:feb9f0f8-60bd-4a23-91da-ccecea58cec7.png)

# %% [markdown]
# <h1>Przefiltrowany sygnał piłokształtny</h1>
# <li>częstotliwość: 10</li>
# <li>częstotliwość graniczna: 50</li>
# <li>próbkowanie: 80</li>
# <li>rząd filtru: 220</li>

# %% [markdown]
# ![pilf.png](attachment:508e5885-b9f5-4c69-b73d-f874fa57d605.png)

# %% [markdown]
# <h1>Generowanie sygnału</h1>

# %%
import scikit_build_example as script

script.genAudio()

# %% [markdown]
# funkcja wykorzystuje bibliotekę AudioFile i przyjmuje następujące parametry:
# <li>częstotliwość graniczna</li>
# <li>rząd filtru</li>

# %% [markdown]
# <h2>Audio bez filtru</h2>

# %% [markdown]
# ![audiobezf.png](attachment:cdedb183-1043-49b3-b06d-46c65381f71c.png)

# %% [markdown]
# <h2>Audio z filtrem</h2>

# %% [markdown]
# <h3>przykład 1</h3>
# <li>częstotliwość graniczna: 15</li>
# <li>rząd filtru: 100</li>

# %% [markdown]
# ![audiozf.png](attachment:e830230b-0172-435e-945e-fa6dec407d2a.png)

# %% [markdown]
# <h3>przykład 2</h3>
# <li>częstotliwość graniczna: 7</li>
# <li>rząd filtru: 150</li>

# %% [markdown]
# ![audiozf2.png](attachment:a9e40487-905a-4247-8ca0-020c32561602.png)
